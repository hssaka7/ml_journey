# %%
# California 1980 housing price dataset 
> This notebook explores the time series dataset using pandas library in python
- toc: true
- branch: master
- comments: true
- author: aakash basnet
- categories: [jupyter]

# %% [markdown]
# # Time series analysis

# %%
url = "https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html"
print("Hello")
